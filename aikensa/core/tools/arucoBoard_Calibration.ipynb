# %%
import cv2
import numpy as np
import os
import datetime
from fpdf import FPDF

# %%
# Initialize ArUco dictionary and parameters for Charuco board
dict_type = cv2.aruco.DICT_4X4_250
squares = (24, 16)
square_length = 0.025
marker_length = 0.020
aruco_dict = cv2.aruco.getPredefinedDictionary(dict_type)


# A4 Paper dimensions in mm are 210 x 297
# Converting these to points: 1 mm = 2.83464567 points
convertVar = 2.83464567

WIDTH_PT = int(420 * convertVar)
HEIGHT_PT = int(297 * convertVar)

PADDING_PT = int(45 * convertVar)  # 5mm padding

resMultiplier = 20

# %%
charboard = cv2.aruco.CharucoBoard(squares, square_length, marker_length, aruco_dict)

# %%
charuco_width = WIDTH_PT - 2*PADDING_PT
charuco_height = HEIGHT_PT - 2*PADDING_PT

# %%
board_with_padding = 255 * np.ones((HEIGHT_PT*resMultiplier, WIDTH_PT*resMultiplier), dtype=np.uint8)
board = charboard.generateImage((charuco_width*resMultiplier, charuco_height*resMultiplier))

# %%
y_offset = (board_with_padding.shape[0] - board.shape[0]) // 2
x_offset = (board_with_padding.shape[1] - board.shape[1]) // 2

# %%
print("board_with_padding shape:", board_with_padding.shape)
print("board shape:", board.shape)
print("x_offset:", x_offset)
print("y_offset:", y_offset)
# Out:
# board_with_padding shape: (16820, 23800)
# board shape: (11740, 18720)
# x_offset: 2540
# y_offset: 2540

# %%
board_with_padding[y_offset:y_offset+board.shape[0], x_offset:x_offset+board.shape[1]] = board

# %%
output_dir = os.path.join(os.getcwd(), "charucoboard")
if not os.path.exists(output_dir):
    os.makedirs(output_dir)

# %%
# Save as PNG
now = datetime.datetime.now()
filename = f"charuco_A3_{now.strftime('%Y_%m_%d_%H%M%S')}.png"
filepath = os.path.join(output_dir, filename)
cv2.imwrite(filepath, board_with_padding)
print("PNG written to:")
print(filepath)
# Out:
# PNG written to:
# /home/sekkei-master/Documents/aikensa_dcam_2go3go/aikensa_dcam/aikensa/core/tools/charucoboard/charuco_A3_2026_02_02_093913.png

# %%
# Save as PDF using FPDF
A1_WIDTH = 1683.78
A1_HEIGHT = 2383.94

# Create a PDF with custom size for A1
pdf = FPDF(orientation='L', unit='pt', format="(A1_WIDTH, A1_HEIGHT)")


pdf.add_page()
pdf.image(filepath, x = 0, y = 0, w = WIDTH_PT, h = HEIGHT_PT)
pdfname = f"charuco_{now.strftime('%Y_%m_%d_%H%M%S')}.pdf"
pdfpath = os.path.join(output_dir, pdfname)
pdf.output(pdfpath)
print("PDF written to:")
print(pdfpath)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[36], line 6
#       3 A1_HEIGHT = 2383.94
#       5 # Create a PDF with custom size for A1
# ----> 6 pdf = FPDF(orientation='L', unit='pt', format="(A1_WIDTH, A1_HEIGHT)")
#       9 pdf.add_page()
#      10 pdf.image(filepath, x = 0, y = 0, w = WIDTH_PT, h = HEIGHT_PT)
#
# File ~/miniconda3/envs/aikensamaster/lib/python3.11/site-packages/fpdf/fpdf.py:104, in FPDF.__init__(self, orientation, unit, format)
#     102     format=(612,1008)
#     103 else:
# --> 104     self.error('Unknown page format: '+format)
#     105 self.fw_pt=format[0]
#     106 self.fh_pt=format[1]
#
# File ~/miniconda3/envs/aikensamaster/lib/python3.11/site-packages/fpdf/fpdf.py:227, in FPDF.error(self, msg)
#     225 def error(self, msg):
#     226     "Fatal error"
# --> 227     raise RuntimeError('FPDF error: '+msg)
#
# RuntimeError: FPDF error: Unknown page format: (a1_width, a1_height)
