# %%
from ultralytics import YOLO

# %%
model_path = "../checkpoints/NISSAN/J42U/P828387YA6A_katabu.pt"

# %%
model = YOLO(model_path)

# %%
print(model.names)
# Out:
# {0: 'CLIP', 1: 'MARKING'}

# %%
#do inferencve of image in folder
image_path = "./img"
results = model(image_path, save=True, save_txt=True, save_crop=True)
print(results)
# Out:
# image 1/1 c:\Users\AIKENSA7GO\Documents\aikensaMaster\aikensa\core\tools\img\20260324_170038_katabu.png: 256x512 (no detections), 22.9ms
# Speed: 1.8ms preprocess, 22.9ms inference, 0.8ms postprocess per image at shape (1, 3, 256, 512)
# Results saved to C:\Users\AIKENSA7GO\Documents\aikensaMaster\aikensa\core\tools\runs\detect\predict
# 0 label saved to C:\Users\AIKENSA7GO\Documents\aikensaMaster\aikensa\core\tools\runs\detect\predict\labels
# [ultralytics.engine.results.Results object with attributes:
#
# boxes: ultralytics.engine.results.Boxes object
# keypoints: None
# masks: None
# names: {0: 'CLIP', 1: 'MARKING'}
# obb: None
# orig_img: array([[[255, 254, 255],
#         [255, 254, 255],
#         [255, 254, 255],
#         ...,
#         [255, 254, 255],
#         [255, 254, 255],
#         [255, 254, 255]],
#
#        [[255, 254, 255],
#         [255, 254, 255],
#         [255, 254, 255],
#         ...,
#         [255, 254, 255],
#         [255, 254, 255],
# ...
