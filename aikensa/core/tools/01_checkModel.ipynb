# %%
from ultralytics import YOLO

# %%
model_path = "../checkpoints/NISSAN/J42U/P828387YA6A_detect.pt"

# %%
model = YOLO(model_path)

# %%
print(model.names)
# Out:
# {0: 'CLIPWHITE', 1: 'CLIPBROWN'}
